# %%
import pandas as pd
import numpy as np

# %%
# Reload dataset
df = pd.read_csv("cleaned_data.csv")

# %%
# ---- Feature Engineering ----

# 1. Touchscreen feature
df["touchscreen"] = df["screenresolution"].apply(lambda x: 1 if "Touchscreen" in x else 0)

# %%
# 2. IPS Panel feature
df["ips_panel"] = df["screenresolution"].apply(lambda x: 1 if "IPS Panel" in x else 0)

# %%
# 3. Extract Resolution and Pixel Count
df["resolution_x"] = df["screenresolution"].str.extract(r'(\d+)x').astype(float)
df["resolution_y"] = df["screenresolution"].str.extract(r'x(\d+)').astype(float)
df["pixel_count"] = df["resolution_x"] * df["resolution_y"]

# %%
# 4. PPI calculation
df["ppi"] = ((df["resolution_x"]**2 + df["resolution_y"]**2) ** 0.5 / df["inches"]).round(2)

# %%
# 5. Clean RAM column (convert from string to int)
df["ram"] = df["ram"].str.replace("GB", "").astype(int)

# %%
# 6. Clean Weight column (convert from string to float)
df["weight"] = df["weight"].str.replace("kg", "").astype(float)

# %%
# ---- Save updated dataset ----
df.to_csv("feature_added_data.csv", index=False)

# %%
# Show new columns
df.head()
# Out:
#    laptop_id company      product   typename  inches  \
# 0          1   Apple  MacBook Pro  Ultrabook    13.3
# 1          2   Apple  Macbook Air  Ultrabook    13.3
# 2          3      HP       250 G6   Notebook    15.6
# 3          4   Apple  MacBook Pro  Ultrabook    15.4
# 4          5   Apple  MacBook Pro  Ultrabook    13.3
#
#                      screenresolution                         cpu  ram  \
# 0  IPS Panel Retina Display 2560x1600        Intel Core i5 2.3GHz    8
# 1                            1440x900        Intel Core i5 1.8GHz    8
# 2                   Full HD 1920x1080  Intel Core i5 7200U 2.5GHz    8
# 3  IPS Panel Retina Display 2880x1800        Intel Core i7 2.7GHz   16
# 4  IPS Panel Retina Display 2560x1600        Intel Core i5 3.1GHz    8
#
#                 memory                           gpu  opsys  weight  \
# 0            128GB SSD  Intel Iris Plus Graphics 640  macOS    1.37
# 1  128GB Flash Storage        Intel HD Graphics 6000  macOS    1.34
# 2            256GB SSD         Intel HD Graphics 620  No OS    1.86
# 3            512GB SSD            AMD Radeon Pro 455  macOS    1.83
# 4            256GB SSD  Intel Iris Plus Graphics 650  macOS    1.37
#
#    price_euros  touchscreen  ips_panel  resolution_x  resolution_y  \
# 0      1339.69            0          1        2560.0        1600.0
# 1       898.94            0          0        1440.0         900.0
# 2       575.00            0          0        1920.0        1080.0
# 3      2537.45            0          1        2880.0        1800.0
# 4      1803.60            0          1        2560.0        1600.0
#
#    pixel_count     ppi
# 0    4096000.0  226.98
# 1    1296000.0  127.68
# 2    2073600.0  141.21
# 3    5184000.0  220.53
# 4    4096000.0  226.98

# %%
df.tail(10)
# Out:
#       laptop_id company                                    product  \
# 1293       1311  Lenovo                         IdeaPad Y700-15ISK
# 1294       1312      HP                        Pavilion 15-AW003nv
# 1295       1313    Dell                              Inspiron 3567
# 1296       1314      HP                           Stream 11-Y000na
# 1297       1315    Asus  X556UJ-XO044T (i7-6500U/4GB/500GB/GeForce
# 1298       1316  Lenovo                             Yoga 500-14ISK
# 1299       1317  Lenovo                             Yoga 900-13ISK
# 1300       1318  Lenovo                         IdeaPad 100S-14IBR
# 1301       1319      HP        15-AC110nv (i7-6500U/6GB/1TB/Radeon
# 1302       1320    Asus        X553SA-XX031T (N3050/4GB/500GB/W10)
#
#                 typename  inches                            screenresolution  \
# 1293            Notebook    15.6                 IPS Panel Full HD 1920x1080
# 1294            Notebook    15.6                           Full HD 1920x1080
# 1295            Notebook    15.6                                    1366x768
# 1296             Netbook    11.6                                    1366x768
# 1297            Notebook    15.6                                    1366x768
# 1298  2 in 1 Convertible    14.0   IPS Panel Full HD / Touchscreen 1920x1080
# 1299  2 in 1 Convertible    13.3  IPS Panel Quad HD+ / Touchscreen 3200x1800
# 1300            Notebook    14.0                                    1366x768
# 1301            Notebook    15.6                                    1366x768
# 1302            Notebook    15.6                                    1366x768
#
#                                        cpu  ram              memory  \
# 1293           Intel Core i7 6700HQ 2.6GHz    8             1TB HDD
# 1294             AMD A9-Series 9410 2.9GHz    6        1.0TB Hybrid
# 1295            Intel Core i7 7500U 2.7GHz    8             1TB HDD
# 1296  Intel Celeron Dual Core N3060 1.6GHz    2  32GB Flash Storage
# 1297            Intel Core i7 6500U 2.5GHz    4           500GB HDD
# 1298            Intel Core i7 6500U 2.5GHz    4           128GB SSD
# 1299            Intel Core i7 6500U 2.5GHz   16           512GB SSD
# 1300  Intel Celeron Dual Core N3050 1.6GHz    2  64GB Flash Storage
# 1301            Intel Core i7 6500U 2.5GHz    6             1TB HDD
# 1302  Intel Celeron Dual Core N3050 1.6GHz    4           500GB HDD
#
#                           gpu       opsys  weight  price_euros  touchscreen  \
# 1293  Nvidia GeForce GTX 960M  Windows 10    2.60       899.00            0
# 1294       AMD Radeon R7 M440  Windows 10    2.04       549.99            0
# 1295       AMD Radeon R5 M430       Linux    2.30       805.99            0
# 1296    Intel HD Graphics 400  Windows 10    1.17       209.00            0
# 1297      Nvidia GeForce 920M  Windows 10    2.20       720.32            0
# 1298    Intel HD Graphics 520  Windows 10    1.80       638.00            1
# 1299    Intel HD Graphics 520  Windows 10    1.30      1499.00            1
# 1300        Intel HD Graphics  Windows 10    1.50       229.00            0
# 1301       AMD Radeon R5 M330  Windows 10    2.19       764.00            0
# 1302        Intel HD Graphics  Windows 10    2.20       369.00            0
#
#       ips_panel  resolution_x  resolution_y  pixel_count     ppi
# 1293          1        1920.0        1080.0    2073600.0  141.21
# 1294          0        1920.0        1080.0    2073600.0  141.21
# 1295          0        1366.0         768.0    1049088.0  100.45
# 1296          0        1366.0         768.0    1049088.0  135.09
# 1297          0        1366.0         768.0    1049088.0  100.45
# 1298          1        1920.0        1080.0    2073600.0  157.35
# 1299          1        3200.0        1800.0    5760000.0  276.05
# 1300          0        1366.0         768.0    1049088.0  111.94
# 1301          0        1366.0         768.0    1049088.0  100.45
# 1302          0        1366.0         768.0    1049088.0  100.45
